# %%
# Statistics Assignment

# %matplotlib inline

# Import what we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math

# Generate list of 100 integers (90-130) for Q1
np.random.seed(42)  # keep it consistent
int_list = np.random.randint(90, 131, 100)
print("First 10 numbers:", int_list[:10], "...")

# Q1(i): Mean function
def calc_mean(numbers):
    total = 0
    for num in numbers:
        total += num
    return total / len(numbers)  # simple average
mean_val = calc_mean(int_list)
print("Mean:", mean_val)

# Q1(ii): Median function
def calc_median(numbers):
    sorted_nums = sorted(numbers)
    n = len(sorted_nums)
    if n % 2 == 0:
        return (sorted_nums[n//2 - 1] + sorted_nums[n//2]) / 2
    return sorted_nums[n//2]
median_val = calc_median(int_list)
print("Median:", median_val)

# Q1(iii): Mode program
def calc_mode(numbers):
    counts = {}
    for num in numbers:
        counts[num] = counts.get(num, 0) + 1
    max_count = max(counts.values())
    modes = [num for num, count in counts.items() if count == max_count]
    if len(modes) == 1:
        return modes[0]
    return f"Multiple modes: {modes}"
mode_val = calc_mode(int_list)
print("Mode:", mode_val)

# Q1(iv): Weighted mean function
def calc_weighted_mean(values, weights):
    weighted_sum = 0
    for v, w in zip(values, weights):
        weighted_sum += v * w
    total_weight = sum(weights)
    return weighted_sum / total_weight
weights = [1] * len(int_list)  # equal weights
w_mean = calc_weighted_mean(int_list, weights)
print("Weighted Mean:", w_mean)

# Q1(v): Geometric mean function
def calc_geometric_mean(numbers):
    product = 1
    for num in numbers:
        product *= num
    return product ** (1 / len(numbers))
geo_mean = calc_geometric_mean(int_list)
print("Geometric Mean:", geo_mean)

# Q1(vi): Harmonic mean function
def calc_harmonic_mean(numbers):
    reciprocal_sum = 0
    for num in numbers:
        reciprocal_sum += 1 / num
    return len(numbers) / reciprocal_sum
h_mean = calc_harmonic_mean(int_list)
print("Harmonic Mean:", h_mean)

# Q1(vii): Midrange function
def calc_midrange(numbers):
    smallest = min(numbers)
    largest = max(numbers)
    return (smallest + largest) / 2
midrange = calc_midrange(int_list)
print("Midrange:", midrange)

# Q1(viii): Trimmed mean function
def calc_trimmed_mean(numbers, percent):
    sorted_nums = sorted(numbers)
    trim_count = int(len(numbers) * percent / 100)
    trimmed_list = sorted_nums[trim_count:-trim_count]
    return calc_mean(trimmed_list)
trimmed_mean = calc_trimmed_mean(int_list, 10)
print("Trimmed Mean (10%):", trimmed_mean)

# Generate list of 500 integers (200-300) for Q2
np.random.seed(42)
int_list2 = np.random.randint(200, 301, 500)
print("First 10 numbers (second list):", int_list2[:10], "...")

# Q2(i): Visualizations
# Frequency & Gaussian
plt.figure(figsize=(8, 5))
plt.hist(int_list2, bins=30, density=True, alpha=0.6, color='blue', label='Frequency')
mu, sigma = calc_mean(int_list2), np.std(int_list2, ddof=1)
x = np.linspace(min(int_list2), max(int_list2), 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma), 'r-', label='Gaussian')
plt.title('Frequency with Gaussian')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('freq_gaussian.png')
plt.show()

# Frequency & KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(int_list2, color='green', label='KDE')
plt.hist(int_list2, bins=30, density=True, alpha=0.5, color='blue', label='Frequency')
plt.title('Frequency with KDE')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('freq_kde.png')
plt.show()

# Gaussian & KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(int_list2, color='green', label='KDE')
plt.plot(x, stats.norm.pdf(x, mu, sigma), 'r-', label='Gaussian')
plt.title('Gaussian with KDE')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('gaussian_kde.png')
plt.show()

# Q2(ii): Range function
def calc_range(numbers):
    return max(numbers) - min(numbers)
range_val = calc_range(int_list2)
print("Range:", range_val)

# Q2(iii): Variance and std dev
def calc_var_std(numbers):
    mean = calc_mean(numbers)
    squared_diff = 0
    for num in numbers:
        squared_diff += (num - mean) ** 2
    variance = squared_diff / len(numbers)
    std = math.sqrt(variance)
    return variance, std
variance, std = calc_var_std(int_list2)
print("Variance:", variance)
print("Standard Deviation:", std)

# Q2(iv): IQR function
def calc_iqr(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return q3 - q1
iqr_val = calc_iqr(int_list2)
print("IQR:", iqr_val)

# Q2(v): Coefficient of variation
def calc_cv(numbers):
    mean = calc_mean(numbers)
    _, std = calc_var_std(numbers)
    return (std / mean) * 100
cv_val = calc_cv(int_list2)
print("Coefficient of Variation (%):", cv_val)

# Q2(vi): Mean absolute deviation
def calc_mad(numbers):
    mean = calc_mean(numbers)
    total_dev = 0
    for num in numbers:
        total_dev += abs(num - mean)
    return total_dev / len(numbers)
mad_val = calc_mad(int_list2)
print("Mean Absolute Deviation:", mad_val)

# Q2(vii): Quartile deviation
def calc_quartile_deviation(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return (q3 - q1) / 2
qd_val = calc_quartile_deviation(int_list2)
print("Quartile Deviation:", qd_val)

# Q2(viii): Range-based coefficient of dispersion
def calc_range_cod(numbers):
    range_val = calc_range(numbers)
    mean = calc_mean(numbers)
    return range_val / mean
cod_val = calc_range_cod(int_list2)
print("Range COD:", cod_val)

# Q3: Discrete random variable class
class DiscreteRandomVariable:
    def __init__(self, vals, probs):
        self.vals = vals
        self.probs = probs

    def expected_val(self):
        total = 0
        for v, p in zip(self.vals, self.probs):
            total += v * p
        return total

    def variance(self):
        mean = self.expected_val()
        var = 0
        for v, p in zip(self.vals, self.probs):
            var += p * (v - mean) ** 2
        return var

rv = DiscreteRandomVariable([1, 2, 3], [0.2, 0.5, 0.3])
print("Expected Value:", rv.expected_val())
print("Variance:", rv.variance())

# Q4: Simulate die rolls
def simulate_die(n=1000):
    rolls = np.random.randint(1, 7, n)
    mean = calc_mean(rolls)
    _, var = calc_var_std(rolls)
    return mean, var
die_mean, die_var = simulate_die()
print("Die Roll Mean:", die_mean)
print("Die Roll Variance:", die_var)

# Q5: Samples from distribution
def sample_dist(dist_type, n=1000, **params):
    if dist_type == 'binomial':
        samples = np.random.binomial(params['n'], params['p'], n)
    elif dist_type == 'poisson':
        samples = np.random.poisson(params['lam'], n)
    mean = calc_mean(samples)
#python
# Statistics Assignment
# Author: [Your Name] - Practicing stats with Python
# Solving all questions with custom calculations

# For Colab/Jupyter visuals
# %matplotlib inline

# Import what we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math

# Generate list of 100 integers (90-130) for Q1
np.random.seed(42)  # keep it consistent
int_list = np.random.randint(90, 131, 100)
print("First 10 numbers:", int_list[:10], "...")

# Q1(i): Mean function
def calc_mean(numbers):
    total = 0
    for num in numbers:
        total += num
    return total / len(numbers)  # simple average
mean_val = calc_mean(int_list)
print("Mean:", mean_val)

# Q1(ii): Median function
def calc_median(numbers):
    sorted_nums = sorted(numbers)
    n = len(sorted_nums)
    if n % 2 == 0:
        return (sorted_nums[n//2 - 1] + sorted_nums[n//2]) / 2
    return sorted_nums[n//2]
median_val = calc_median(int_list)
print("Median:", median_val)

# Q1(iii): Mode program
def calc_mode(numbers):
    counts = {}
    for num in numbers:
        counts[num] = counts.get(num, 0) + 1
    max_count = max(counts.values())
    modes = [num for num, count in counts.items() if count == max_count]
    if len(modes) == 1:
        return modes[0]
    return f"Multiple modes: {modes}"
mode_val = calc_mode(int_list)
print("Mode:", mode_val)

# Q1(iv): Weighted mean function
def calc_weighted_mean(values, weights):
    weighted_sum = 0
    for v, w in zip(values, weights):
        weighted_sum += v * w
    total_weight = sum(weights)
    return weighted_sum / total_weight
weights = [1] * len(int_list)  # equal weights
w_mean = calc_weighted_mean(int_list, weights)
print("Weighted Mean:", w_mean)

# Q1(v): Geometric mean function
def calc_geometric_mean(numbers):
    product = 1
    for num in numbers:
        product *= num
    return product ** (1 / len(numbers))
geo_mean = calc_geometric_mean(int_list)
print("Geometric Mean:", geo_mean)

# Q1(vi): Harmonic mean function
def calc_harmonic_mean(numbers):
    reciprocal_sum = 0
    for num in numbers:
        reciprocal_sum += 1 / num
    return len(numbers) / reciprocal_sum
h_mean = calc_harmonic_mean(int_list)
print("Harmonic Mean:", h_mean)

# Q1(vii): Midrange function
def calc_midrange(numbers):
    smallest = min(numbers)
    largest = max(numbers)
    return (smallest + largest) / 2
midrange = calc_midrange(int_list)
print("Midrange:", midrange)

# Q1(viii): Trimmed mean function
def calc_trimmed_mean(numbers, percent):
    sorted_nums = sorted(numbers)
    trim_count = int(len(numbers) * percent / 100)
    trimmed_list = sorted_nums[trim_count:-trim_count]
    return calc_mean(trimmed_list)
trimmed_mean = calc_trimmed_mean(int_list, 10)
print("Trimmed Mean (10%):", trimmed_mean)

# Generate list of 500 integers (200-300) for Q2
np.random.seed(42)
int_list2 = np.random.randint(200, 301, 500)
print("First 10 numbers (second list):", int_list2[:10], "...")

# Q2(i): Visualizations
# Frequency & Gaussian
plt.figure(figsize=(8, 5))
plt.hist(int_list2, bins=30, density=True, alpha=0.6, color='blue', label='Frequency')
mu, sigma = calc_mean(int_list2), np.std(int_list2, ddof=1)
x = np.linspace(min(int_list2), max(int_list2), 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma), 'r-', label='Gaussian')
plt.title('Frequency with Gaussian')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('freq_gaussian.png')
plt.show()

# Frequency & KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(int_list2, color='green', label='KDE')
plt.hist(int_list2, bins=30, density=True, alpha=0.5, color='blue', label='Frequency')
plt.title('Frequency with KDE')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('freq_kde.png')
plt.show()

# Gaussian & KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(int_list2, color='green', label='KDE')
plt.plot(x, stats.norm.pdf(x, mu, sigma), 'r-', label='Gaussian')
plt.title('Gaussian with KDE')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.savefig('gaussian_kde.png')
plt.show()

# Q2(ii): Range function
def calc_range(numbers):
    return max(numbers) - min(numbers)
range_val = calc_range(int_list2)
print("Range:", range_val)

# Q2(iii): Variance and std dev
def calc_var_std(numbers):
    mean = calc_mean(numbers)
    squared_diff = 0
    for num in numbers:
        squared_diff += (num - mean) ** 2
    variance = squared_diff / len(numbers)
    std = math.sqrt(variance)
    return variance, std
variance, std = calc_var_std(int_list2)
print("Variance:", variance)
print("Standard Deviation:", std)

# Q2(iv): IQR function
def calc_iqr(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return q3 - q1
iqr_val = calc_iqr(int_list2)
print("IQR:", iqr_val)

# Q2(v): Coefficient of variation
def calc_cv(numbers):
    mean = calc_mean(numbers)
    _, std = calc_var_std(numbers)
    return (std / mean) * 100
cv_val = calc_cv(int_list2)
print("Coefficient of Variation (%):", cv_val)

# Q2(vi): Mean absolute deviation
def calc_mad(numbers):
    mean = calc_mean(numbers)
    total_dev = 0
    for num in numbers:
        total_dev += abs(num - mean)
    return total_dev / len(numbers)
mad_val = calc_mad(int_list2)
print("Mean Absolute Deviation:", mad_val)

# Q2(vii): Quartile deviation
def calc_quartile_deviation(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return (q3 - q1) / 2
qd_val = calc_quartile_deviation(int_list2)
print("Quartile Deviation:", qd_val)

# Q2(viii): Range-based coefficient of dispersion
def calc_range_cod(numbers):
    range_val = calc_range(numbers)
    mean = calc_mean(numbers)
    return range_val / mean
cod_val = calc_range_cod(int_list2)
print("Range COD:", cod_val)

# Q3: Discrete random variable class
class DiscreteRandomVariable:
    def __init__(self, vals, probs):
        self.vals = vals
        self

# Q6: Gaussian samples
def gaussian_samples(n=1000, mu=0, sigma=1):
    samples = np.random.normal(mu, sigma, n)
    mean = calc_mean(samples)
    var, std = calc_var_std(samples)
    return mean, var, std
g_mean, g_var, g_std = gaussian_samples()
print("Gaussian Mean:", g_mean)
print("Gaussian Variance:", g_var)
print("Gaussian Std Dev:", g_std)

# Q7: Tips dataset analysis
tips = sns.load_dataset('tips')
bill = tips['total_bill']
tip = tips['tip']

# Q7(i): Skewness
def calc_skew(data):
    mean = calc_mean(data)
    n = len(data)
    std = calc_var_std(data)[1]
    skew_sum = 0
    for x in data:
        skew_sum += (x - mean) ** 3
    return skew_sum / (n * std ** 3)
bill_skew = calc_skew(bill)
tip_skew = calc_skew(tip)
print("Total Bill Skewness:", bill_skew)
print("Tip Skewness:", tip_skew)

# Q7(ii): Skewness type
def skew_type(skew):
    if skew > 0.5:
        return "Positive skewness"
    elif skew < -0.5:
        return "Negative skewness"
    return "Approximately symmetric"
print("Total Bill Skewness Type:", skew_type(bill_skew))
print("Tip Skewness Type:", skew_type(tip_skew))

# Q7(iii): Covariance
def calc_cov(x, y):
    mean_x = calc_mean(x)
    mean_y = calc_mean(y)
    cov_sum = 0
    for xi, yi in zip(x, y):
        cov_sum += (xi - mean_x) * (yi - mean_y)
    return cov_sum / len(x)
cov_val = calc_cov(bill, tip)
print("Covariance:", cov_val)

# Q7(iv): Pearson correlation
def calc_pearson(x, y):
    cov = calc_cov(x, y)
    std_x = calc_var_std(x)[1]
    std_y = calc_var_std(y)[1]
    return cov / (std_x * std_y)
pearson_val = calc_pearson(bill, tip)
print("Pearson Correlation:", pearson_val)

# Q7(v): Scatter plot
plt.scatter(bill, tip, color='blue', alpha=0.5)
plt.title('Bill vs Tip Scatter')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.savefig('bill_tip_scatter.png')
plt.show()

# Q8: Normal PDF
def normal_pdf(x, mu, sigma):
    return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-((x - mu) ** 2) / (2 * sigma ** 2))
pdf_val = normal_pdf(0, 0, 1)
print("Normal PDF at x=0:", pdf_val)

# Q9: Exponential CDF
def exp_cdf(x, lam):
    if x < 0:
        return 0
    return 1 - math.exp(-lam * x)
cdf_val = exp_cdf(1, 1)
print("Exponential CDF at x=1:", cdf_val)

# Q10: Poisson PMF
def poisson_pmf(k, lam):
    return (lam ** k * math.exp(-lam)) / math.factorial(k)
pmf_val = poisson_pmf(2, 3)
print("Poisson PMF at k=2:", pmf_val)

# Q11: Z-test for layouts
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)
def z_test_props(x1, n1, x2, n2):
    p1 = x1 / n1
    p2 = x2 / n2
    p = (x1 + x2) / (n1 + n2)
    se = math.sqrt(p * (1 - p) * (1/n1 + 1/n2))
    z = (p1 - p2) / se
    p_val = 2 * (1 - stats.norm.cdf(abs(z)))
    return z, p_val
z, p_val = z_test_props(50, 1000, 70, 1000)
print("Z-test Z:", z)
print("Z-test P-value:", p_val)
print("New layout better?:", p_val < 0.05)

# Q12: T-test for tutoring
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
t, p_val = stats.ttest_rel(before_program, after_program)
print("T-test T:", t)
print("T-test P-value:", p_val)
print("Program effective?:", p_val < 0.05)

# Q13: T-test for drug
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
t, p_val = stats.ttest_rel(before_drug, after_drug)
print("T-test T:", t)
print("T-test P-value:", p_val)
print("Drug effective?:", p_val < 0.05)

# Q14: Z-test for response time
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
def z_test_mean(data, mu):
    mean = calc_mean(data)
    sigma = calc_var_std(data)[1]
    n = len(data)
    z = (mean - mu) / (sigma / math.sqrt(n))
    p_val = stats.norm.cdf(z)  # one-tailed
    return z, p_val
z, p_val = z_test_mean(response_times, 5)
print("Z-test Z:", z)
print("Z-test P-value:", p_val)
print("Response time < 5 min?:", p_val < 0.05)

# Q15: T-test for layouts
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]
def ab_test(data1, data2):
    t, p_val = stats.ttest_ind(data1, data2)
    df = len(data1) + len(data2) - 2
    return t, df, p_val
t, df, p_val = ab_test(layout_a_clicks, layout_b_clicks)
print("T-test T:", t)
print("Degrees of Freedom:", df)
print("T-test P-value:", p_val)
print("Layouts differ?:", p_val < 0.05)

# Q16: T-test for drugs
existing_drug = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]
t, df, p_val = ab_test(existing_drug, new_drug)
print("T-test T:", t)
print("Degrees of Freedom:", df)
print("T-test P-value:", p_val)
print("New drug better?:", p_val < 0.05)

# Q17: T-test for intervention
pre_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
t, p_val = stats.ttest_rel(pre_scores, post_scores)
print("T-test T:", t)
print("T-test P-value:", p_val)
print("Intervention effective?:", p_val < 0.05)

# Q18: T-test for salaries
np.random.seed(0)
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)
t, df, p_val = ab_test(male_salaries, female_salaries)
print("T-test T:", t)
print("Degrees of Freedom:", df)
print("T-test P-value:", p_val)
print("Salary gap?:", p_val < 0.05)

# Q19: T-test for product versions
version1 = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2 = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]
t, df, p_val = ab_test(version1, version2)
print("T-test T:", t)
print("Degrees of Freedom:", df)
print("T-test P-value:", p_val)
print("Quality differs?:", p_val < 0.05)

# Q20: T-test for branches
# Using first 50 values due to repetition
branch_a = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5][:50]
branch_b = [3, 4, 4, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 3, 5, 4, 3, 4, 5, 4, 4, 5, 3, 4, 5, 4, 3, 5, 4, 4, 3, 4, 5, 4, 3, 5, 4, 4, 3, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 3][:50]
t, df, p_val = ab_test(branch_a, branch_b)
print("T-test T:", t)
print("Degrees of Freedom:", df)
print("T-test P-value:", p_val)
print("Satisfaction differs?:", p_val < 0.05)

# Q22: Chi-square for satisfaction vs region
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])
chi2, p_val, dof, _ = stats.chi2_contingency(data)
print("Chi-square Statistic:", chi2)
print("Chi-square P-value:", p_val)
print("Significant relationship?:", p_val < 0.05)

# Q23: Chi-square for training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])
chi2, p_val, dof, _ = stats.chi2_contingency(data)
print("Chi-square Statistic:", chi2)
print("Chi-square P-value:", p_val)
print("Performance differs?:", p_val < 0.05)

# Q24: ANOVA for product versions
standard = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]
f_stat, p_val = stats.f_oneway(standard, premium, deluxe)
print("ANOVA F-statistic:", f_stat)
print("ANOVA P-value:", p_val)
print("Scores differ?:", p_val < 0.05)
# Out:
# First 10 numbers: [128 118 104  97 110 128 108 112 100 100] ...
# Mean: 108.94
# Median: 109.5
# Mode: Multiple modes: [np.int64(97), np.int64(113)]
# Weighted Mean: 108.94
# Geometric Mean: 0.0
# Harmonic Mean: 107.68717366618075
# Midrange: 110.0
# Trimmed Mean (10%): 108.675
# First 10 numbers (second list): [251 292 214 271 260 220 282 286 274 274] ...
# <ipython-input-19-de507ae99598>:65: RuntimeWarning: overflow encountered in scalar multiply
#   product *= num
# Range: 100
# Variance: 901.3499000000006
# Standard Deviation: 30.022489903404093
# IQR: 51.25
# Coefficient of Variation (%): 12.03740423535708
# Mean Absolute Deviation: 25.803440000000002
# Quartile Deviation: 25.625
# Range COD: 0.40094623311013994
# Expected Value: 2.0999999999999996
# Variance: 0.49
# Die Roll Mean: 3.509
# Die Roll Variance: 1.722184368759639
# First 10 numbers: [128 118 104  97 110 128 108 112 100 100] ...
# Mean: 108.94
# Median: 109.5
# Mode: Multiple modes: [np.int64(97), np.int64(113)]
# ...
